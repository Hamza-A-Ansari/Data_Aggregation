# %% [markdown]
# # Data Aggregation
#
#    * The process of compiling typically large amounts of information from a given dataset and     organizing into a more consumable and comprehensive medium is called Data Aggregation

# %% [markdown]
# #### Import necessary modules

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# #### Load a csv file into a Pandas DataFrame

# %%
dataset = pd.read_csv("World Happiness Data 2016.csv")

# %%
dataset.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# 2                   1.42666  1.18326                   0.86733  0.56624
# 3                   1.57744  1.12690                   0.79579  0.59609
# 4                   1.40598  1.13464                   0.81091  0.57104
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463
# 2                        0.14975     0.47678            2.83137
# 3                        0.35776     0.37895            2.66465
# 4                        0.41004     0.25492            2.82596

# %% [markdown]
# ### unique() function
#    * It is used to get unique values of series object
#    * Uniques are returned in order of appearence
#    * Syntax: Series.unique(self)

# %%
region = dataset["Region"].unique()

# %%
region
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %% [markdown]
# ### Extracting countries lying in Southeastern Asian region

# %%
dataset[dataset["Region"] == "Southeastern Asia"]
# Out:
#          Country             Region  Happiness Rank  Happiness Score  \
# 21     Singapore  Southeastern Asia              22            6.739
# 32      Thailand  Southeastern Asia              33            6.474
# 46      Malaysia  Southeastern Asia              47            6.005
# 78     Indonesia  Southeastern Asia              79            5.314
# 81   Philippines  Southeastern Asia              82            5.279
# 95       Vietnam  Southeastern Asia              96            5.061
# 101         Laos  Southeastern Asia             102            4.876
# 118      Myanmar  Southeastern Asia             119            4.395
# 139     Cambodia  Southeastern Asia             140            3.907
#
#      Lower Confidence Interval  Upper Confidence Interval  \
# 21                       6.674                      6.804
# 32                       6.396                      6.552
# 46                       5.921                      6.089
# 78                       5.237                      5.391
# 81                       5.160                      5.398
# 95                       4.991                      5.131
# 101                      4.742                      5.010
# 118                      4.327                      4.463
# 139                      3.798                      4.016
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 21                    1.64555  0.86758                   0.94719  0.48770
# 32                    1.08930  1.04477                   0.64915  0.49553
# 46                    1.25142  0.88025                   0.62366  0.39031
# 78                    0.95104  0.87625                   0.49374  0.39237
# 81                    0.81217  0.87877                   0.47036  0.54854
# 95                    0.74037  0.79117                   0.66157  0.55954
# 101                   0.68042  0.54970                   0.38291  0.52168
# 118                   0.34112  0.69981                   0.39880  0.42692
# 139                   0.55604  0.53750                   0.42494  0.58852
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 21                         0.46987     0.32706            1.99375
# 32                         0.02833     0.58696            2.57960
# 46                         0.09081     0.41474            2.35384
# 78                         0.00322     0.56521            2.03171
# 81                         0.11757     0.21674            2.23484
# 95                         0.11556     0.25075            1.94180
# 101                        0.22423     0.43079            2.08637
# 118                        0.20243     0.81971            1.50655
# 139                        0.08092     0.40339            1.31573

# %% [markdown]
# ### Finding average happiness score for each region using for loop

# %%
region_avg_happ_score = {}

for i in region: #Wester Europe
    avg_happ_score = dataset[dataset["Region"] == i]["Happiness Score"].mean()
    region_avg_happ_score[i] = round(avg_happ_score,2)

# %%
region_avg_happ_score
# Out:
# {'Western Europe': 6.69,
#  'North America': 7.25,
#  'Australia and New Zealand': 7.32,
#  'Middle East and Northern Africa': 5.39,
#  'Latin America and Caribbean': 6.1,
#  'Southeastern Asia': 5.34,
#  'Central and Eastern Europe': 5.37,
#  'Eastern Asia': 5.62,
#  'Sub-Saharan Africa': 4.14,
#  'Southern Asia': 4.56}

# %% [markdown]
# #### Groupby on Region

# %%
region_group = dataset.groupby("Region")

# %%
region_group

# %% [markdown]
# #### Mean of Western Europe

# %%
region_group.get_group("Western Europe").mean()
# Out:
# Happiness Rank                   29.190476
# Happiness Score                   6.685667
# Lower Confidence Interval         6.604571
# Upper Confidence Interval         6.766762
# Economy (GDP per Capita)          1.417056
# Family                            1.042452
# Health (Life Expectancy)          0.825754
# Freedom                           0.477587
# Trust (Government Corruption)     0.232544
# Generosity                        0.304715
# Dystopia Residual                 2.385576
# dtype: float64

# %% [markdown]
# ### Finding averege happiness score for each region using group

# %%
region_avg_happ_score = {}

for i in region:
    avg_happ_score = region_group.get_group(i)["Happiness Score"].mean()
    region_avg_happ_score[i] = round(avg_happ_score,2)

# %%
region_avg_happ_score
# Out:
# {'Western Europe': 6.69,
#  'North America': 7.25,
#  'Australia and New Zealand': 7.32,
#  'Middle East and Northern Africa': 5.39,
#  'Latin America and Caribbean': 6.1,
#  'Southeastern Asia': 5.34,
#  'Central and Eastern Europe': 5.37,
#  'Eastern Asia': 5.62,
#  'Sub-Saharan Africa': 4.14,
#  'Southern Asia': 4.56}

# %%
region_group["Happiness Score"].mean()
# Out:
# Region
# Australia and New Zealand          7.323500
# Central and Eastern Europe         5.370690
# Eastern Asia                       5.624167
# Latin America and Caribbean        6.101750
# Middle East and Northern Africa    5.386053
# North America                      7.254000
# Southeastern Asia                  5.338889
# Southern Asia                      4.563286
# Sub-Saharan Africa                 4.136421
# Western Europe                     6.685667
# Name: Happiness Score, dtype: float64

# %% [markdown]
# ### Finding averages of all columns under grouped regions

# %%
region_group.mean().round(2)
# Out:
#                                  Happiness Rank  Happiness Score  \
# Region
# Australia and New Zealand                  8.50             7.32
# Central and Eastern Europe                78.45             5.37
# Eastern Asia                              67.17             5.62
# Latin America and Caribbean               48.33             6.10
# Middle East and Northern Africa           78.11             5.39
# North America                              9.50             7.25
# Southeastern Asia                         80.00             5.34
# Southern Asia                            111.71             4.56
# Sub-Saharan Africa                       129.66             4.14
# Western Europe                            29.19             6.69
#
#                                  Lower Confidence Interval  \
# Region
# Australia and New Zealand                             7.25
# Central and Eastern Europe                            5.28
# Eastern Asia                                          5.55
# Latin America and Caribbean                           5.98
# Middle East and Northern Africa                       5.27
# North America                                         7.18
# Southeastern Asia                                     5.25
# Southern Asia                                         4.49
# Sub-Saharan Africa                                    4.02
# Western Europe                                        6.60
#
#                                  Upper Confidence Interval  \
# Region
# Australia and New Zealand                             7.39
# Central and Eastern Europe                            5.46
# Eastern Asia                                          5.70
# Latin America and Caribbean                           6.23
# Middle East and Northern Africa                       5.50
# North America                                         7.33
# Southeastern Asia                                     5.43
# Southern Asia                                         4.64
# Sub-Saharan Africa                                    4.25
# Western Europe                                        6.77
#
#                                  Economy (GDP per Capita)  Family  \
# Region
# Australia and New Zealand                            1.40    1.14
# Central and Eastern Europe                           1.05    0.86
# Eastern Asia                                         1.28    0.91
# Latin America and Caribbean                          0.99    0.90
# Middle East and Northern Africa                      1.14    0.70
# North America                                        1.47    1.07
# Southeastern Asia                                    0.90    0.79
# Southern Asia                                        0.66    0.48
# Sub-Saharan Africa                                   0.47    0.59
# Western Europe                                       1.42    1.04
#
#                                  Health (Life Expectancy)  Freedom  \
# Region
# Australia and New Zealand                            0.84     0.57
# Central and Eastern Europe                           0.63     0.30
# Eastern Asia                                         0.81     0.39
# Latin America and Caribbean                          0.61     0.43
# Middle East and Northern Africa                      0.62     0.31
# North America                                        0.80     0.53
# Southeastern Asia                                    0.56     0.49
# Southern Asia                                        0.45     0.35
# Sub-Saharan Africa                                   0.24     0.32
# Western Europe                                       0.83     0.48
#
#                                  Trust (Government Corruption)  Generosity  \
# Region
# Australia and New Zealand                                 0.37        0.48
# Central and Eastern Europe                                0.09        0.17
# Eastern Asia                                              0.12        0.22
# Latin America and Caribbean                               0.11        0.21
# Middle East and Northern Africa                           0.16        0.19
# North America                                             0.23        0.43
# Southeastern Asia                                         0.15        0.45
# Southern Asia                                             0.10        0.34
# Sub-Saharan Africa                                        0.12        0.23
# Western Europe                                            0.23        0.30
#
#                                  Dystopia Residual
# Region
# Australia and New Zealand                     2.51
# Central and Eastern Europe                    2.27
# Eastern Asia                                  1.90
# Latin America and Caribbean                   2.86
# Middle East and Northern Africa               2.28
# North America                                 2.72
# Southeastern Asia                             2.00
# Southern Asia                                 2.17
# Sub-Saharan Africa                            2.17
# Western Europe                                2.39

# %% [markdown]
# #### Size of all grouped regions

# %%
region_group.size()
# Out:
# Region
# Australia and New Zealand           2
# Central and Eastern Europe         29
# Eastern Asia                        6
# Latin America and Caribbean        24
# Middle East and Northern Africa    19
# North America                       2
# Southeastern Asia                   9
# Southern Asia                       7
# Sub-Saharan Africa                 38
# Western Europe                     21
# dtype: int64

# %% [markdown]
# ### Finding Aggregate Function of "Happiness Score"

# %%
happiness_score = region_group["Happiness Score"]

# %%
agg_func = happiness_score.agg(["mean","max","min","count","sum"])

# %%
agg_func.columns= ["Happiness_mean","Happiness_max","Happiness_min","Happiness_count","Happiness_sum"]

# %%
agg_func
# Out:
#                                  Happiness_mean  Happiness_max  Happiness_min  \
# Region
# Australia and New Zealand              7.323500          7.334          7.313
# Central and Eastern Europe             5.370690          6.596          4.217
# Eastern Asia                           5.624167          6.379          4.907
# Latin America and Caribbean            6.101750          7.087          4.028
# Middle East and Northern Africa        5.386053          7.267          3.069
# North America                          7.254000          7.404          7.104
# Southeastern Asia                      5.338889          6.739          3.907
# Southern Asia                          4.563286          5.196          3.360
# Sub-Saharan Africa                     4.136421          5.648          2.905
# Western Europe                         6.685667          7.526          5.033
#
#                                  Happiness_count  Happiness_sum
# Region
# Australia and New Zealand                      2         14.647
# Central and Eastern Europe                    29        155.750
# Eastern Asia                                   6         33.745
# Latin America and Caribbean                   24        146.442
# Middle East and Northern Africa               19        102.335
# North America                                  2         14.508
# Southeastern Asia                              9         48.050
# Southern Asia                                  7         31.943
# Sub-Saharan Africa                            38        157.184
# Western Europe                                21        140.399

# %% [markdown]
# ### Pivot Table of DataSet

# %%
dataset.pivot_table(index = "Region", values = "Happiness Score", aggfunc = ["mean","max","min"], margins = True)
# Out:
#                                            mean             max  \
#                                 Happiness Score Happiness Score
# Region
# Australia and New Zealand              7.323500           7.334
# Central and Eastern Europe             5.370690           6.596
# Eastern Asia                           5.624167           6.379
# Latin America and Caribbean            6.101750           7.087
# Middle East and Northern Africa        5.386053           7.267
# North America                          7.254000           7.404
# Southeastern Asia                      5.338889           6.739
# Southern Asia                          4.563286           5.196
# Sub-Saharan Africa                     4.136421           5.648
# Western Europe                         6.685667           7.526
# All                                    5.382185           7.526
#
#                                             min
#                                 Happiness Score
# Region
# Australia and New Zealand                 7.313
# Central and Eastern Europe                4.217
# Eastern Asia                              4.907
# Latin America and Caribbean               4.028
# Middle East and Northern Africa           3.069
# North America                             7.104
# Southeastern Asia                         3.907
# Southern Asia                             3.360
# Sub-Saharan Africa                        2.905
# Western Europe                            5.033
# All                                       2.905
